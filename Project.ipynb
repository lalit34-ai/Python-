# %%
import os
import matplotlib.pyplot as plt
#for loading and visualizing audio filesg
import librosa
import librosa.display
#to play audio
import IPython.display as ipd

# %%
import pandas as pd
df=pd.read_csv('D:\Education\College\sem 10\overview-of-recordings.csv')
df.head()
# Out:
#    audio_clipping  audio_clipping:confidence background_noise_audible  \
# 0     no_clipping                     1.0000              light_noise
# 1  light_clipping                     0.6803                 no_noise
# 2     no_clipping                     1.0000                 no_noise
# 3     no_clipping                     1.0000              light_noise
# 4     no_clipping                     1.0000                 no_noise
#
#    background_noise_audible:confidence  overall_quality_of_the_audio  \
# 0                               1.0000                          3.33
# 1                               0.6803                          3.33
# 2                               0.6655                          3.33
# 3                               1.0000                          3.33
# 4                               1.0000                          4.67
#
#      quiet_speaker  quiet_speaker:confidence  speaker_id  \
# 0  audible_speaker                       1.0    43453425
# ...

# %%
import glob,wave

# %%
Folder='D:\\Education\\College\\sem 10\\recordings\\train'
zero = []
path = Folder
for filename in glob.glob(os.path.join(path, '*.wav')):
    w = wave.open(filename, 'r')
    d = w.readframes(w.getnframes())
    zero.append(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-2c927c1894ac> in <module>
#       2 zero = []
#       3 path = Folder
# ----> 4 for filename in glob.glob(os.path.join(path, '*.wav')):
#       5     w = wave.open(filename, 'r')
#       6     d = w.readframes(w.getnframes())
#
# NameError: name 'glob' is not defined

# %%
Folder='D:\\Education\\College\\sem 10\\recordings\\train'
dir_list = os.listdir(Folder)
# a=[]
# for i in dir_list:
#     #print(i)
#     a.append[i]
    
    
# sound_filenames=[]
# for filenames in os.walk(Folder):
#     for filename in filenames:
#         #print(os.path.join(dirname, filename))
#         if os.path.join(filename).split('/')[-1].split('.')[-1]=='ogg':
#             sound_filenames.append(os.path.join(filename))
        
# print("Total Sound Files : ",len(sound_filenames))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-6daca95530e7> in <module>
#      11     for filename in filenames:
#      12         #print(os.path.join(dirname, filename))
# ---> 13         if os.path.join(filename).split('/')[-1].split('.')[-1]=='ogg':
#      14             sound_filenames.append(os.path.join(filename))
#      15
#
# ~\anaconda3\lib\ntpath.py in join(path, *paths)
#      74 # Join two (or more) paths.
#      75 def join(path, *paths):
# ---> 76     path = os.fspath(path)
#      77     if isinstance(path, bytes):
#      78         sep = b'\\'
#
# TypeError: expected str, bytes or os.PathLike object, not list

# %%
for i in dir_list[:5]:
    Path=Folder
    directory=os.listdir(Path)
    x, sr = librosa.load(Path+'/'+directory[0], sr=22100)
    plt.figure(figsize=(14, 5))
    librosa.display.waveshow(x, sr=sr)

# %%
#Path=Folder
#directory=os.listdir(Path)
#x, sr = librosa.load(Path, sr=44100)  # sample rate
#print(type(x), type(sr))
#print(x.shape, sr)   
def plot_spectogram(Folder):
    signal, sr = librosa.load(Folder, duration=10)
    print(signal,sr)
    plt.figure(figsize=(10, 4))
    D = librosa.amplitude_to_db(np.abs(librosa.stft(signal)), ref=np.max)
    librosa.display.specshow(D, y_axis="linear")
    plt.colorbar(format="%+2.0f dB")
    plt.title("Linear-frequency power spectrogram")
    plt.show()
    print('\n\n')

#Plotting Spectogram of 5 audio files
for path in zero[:5]:
    plot_spectogram(path)
# Out:
# C:\Users\lalit\anaconda3\lib\site-packages\librosa\core\audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\librosa\core\audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     148     try:
# --> 149         with sf.SoundFile(path) as sf_desc:
#     150             sr_native = sf_desc.samplerate
#
# ~\anaconda3\lib\site-packages\soundfile.py in __init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     628                                          format, subtype, endian)
# --> 629         self._file = self._open(file, mode_int, closefd)
#     630         if set(mode).issuperset('r+') and self.seekable():
#
# ...

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(nrows=1, ncols=3, sharex=True)
plt.figure(figsize=(60, 80))
for i in dir_list[:1]:
    z=0
    Path=Folder + '\'
    directory=os.listdir(Path)
    x, sr = librosa.load(Path+'/'+directory[0], sr=44100)  
    X = librosa.stft(x)
    Xdb = librosa.amplitude_to_db(abs(X))
    plt.figure(figsize=(14, 5))
    librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='mel',ax=ax[0,0])
    librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log',ax=ax[0,1])
    librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='cqt_hz',ax=ax[0,2])
    z+=1
# Out:
#   File "<ipython-input-24-e3069d601133>", line 6
#     Path=Folder+'\'
#                    ^
# SyntaxError: EOL while scanning string literal

# %%
import numpy as np
sr = 10050 # sample rate
T = 5.0    # seconds
t = np.linspace(0, T, int(T*sr), endpoint=False) # time variable
x = 0.1*np.tan(2*np.pi*220*t)# pure sine wave at 220 Hz

ipd.Audio(x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
for i in dir_list[1:2]:
    Path=Folder+'/'+i
    directory=os.listdir(Path)
    n_mels = 128
    mel = librosa.filters.mel(sr=sr, n_fft=n_fft, n_mels=n_mels)
    y, sr = librosa.load(Path+'/'+directory[0], sr=44100)  
    whale_song, _ = librosa.effects.trim(y)
    S = librosa.feature.melspectrogram(whale_song, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
    S_DB = librosa.power_to_db(S, ref=np.max)
    librosa.display.specshow(S_DB, sr=sr, hop_length=hop_length, x_axis='time', y_axis='mel');
    plt.colorbar(format='%+2.0f dB');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-7d49254999e1> in <module>
#       6     directory=os.listdir(Path)
#       7     n_mels = 128
# ----> 8     mel = librosa.filters.mel(sr=sr, n_fft=n_fft, n_mels=n_mels)
#       9     y, sr = librosa.load(Path+'/'+directory[0], sr=44100)
#      10     whale_song, _ = librosa.effects.trim(y)
#
# NameError: name 'n_fft' is not defined

# %%
import librosa
audio_path = Path+'/'+directory[0]
x , sr = librosa.load(audio_path)
print(type(x), type(sr))
print(len(x))

# %%
#display waveform
import librosa.display
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display
plt.figure(figsize=(14, 5))
librosa.display.waveshow(x, sr=sr)

# %%
n0 = 9000
n1 = 9100
plt.figure(figsize=(14, 5))
plt.plot(x[n0:n1])
plt.grid()

# %%
zero_crossings = librosa.zero_crossings(x[n0:n1], pad=False)
print(sum(zero_crossings))
# Out:
# 2

# %%
mfccs = librosa.feature.mfcc(x, sr=sr)
print(mfccs.shape)
#Displaying  the MFCCs:
librosa.display.specshow(mfccs, sr=sr, x_axis='time')
# Out:
# (20, 218)

# %%
spectral_rolloff = librosa.feature.spectral_rolloff(x, sr=sr)[0]
librosa.display.waveshow(x, sr=sr, alpha=0.4)
plt.plot(t, normalize(spectral_rolloff), color='r')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-9f33f3e34859> in <module>
#       1 spectral_rolloff = librosa.feature.spectral_rolloff(x, sr=sr)[0]
#       2 librosa.display.waveshow(x, sr=sr, alpha=0.4)
# ----> 3 plt.plot(t, normalize(spectral_rolloff), color='r')
#
# NameError: name 'normalize' is not defined

# %%
from scipy.io import wavfile
freq_sample, sig_audio = wavfile.read(Path+'/'+directory[0])
# Output the parameters: Signal Data Type, Sampling Frequency and Duration
print('\nShape of Signal:', sig_audio.shape)
print('Signal Datatype:', sig_audio.dtype)
print('Signal duration:', round(sig_audio.shape[0] / float(freq_sample), 2), 'seconds')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-37-bca0e20522f5> in <module>
#       1 from scipy.io import wavfile
# ----> 2 freq_sample, sig_audio = wavfile.read(Path+'/'+directory[0])
#       3 # Output the parameters: Signal Data Type, Sampling Frequency and Duration
#       4 print('\nShape of Signal:', sig_audio.shape)
#       5 print('Signal Datatype:', sig_audio.dtype)
#
# ~\anaconda3\lib\site-packages\scipy\io\wavfile.py in read(filename, mmap)
#     262         mmap = False
#     263     else:
# --> 264         fid = open(filename, 'rb')
#     265
#     266     try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\Education\\College\\sem 10\\recordings\\train1249120_44142156_100535941.wav/1249120_44142156_100535941.wav'

# %%
import librosa.display
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display
Path=Folder+'/amewig'
directory=os.listdir(Path)
audio_path = Path+'/'+directory[0]
signal, sr = librosa.load(audio_path, sr = None)
print(audio_path)
plt.figure(figsize=(14, 5))
librosa.display.waveshow(signal, sr=sr)

# %%
X = librosa.stft(signal)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
plt.colorbar()

# %%
import librosa.display
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display
Path=Folder+'/categr'
directory=os.listdir(Path)
audio_path = Path+'/'+directory[0]
signal, sr = librosa.load(audio_path, sr = None)
print(audio_path)
plt.figure(figsize=(14, 5))
librosa.display.waveshow(signal, sr=sr)

# %%
X = librosa.stft(signal)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
plt.colorbar()

# %%
pd.Series([1,2,3,4])

# %%
from pydub import AudioSegment

# %%
from pydub import AudioSegment 
from pydub.utils import make_chunks
import os

def process_sudio(file_name):
    print(file_name)
    myaudio = AudioSegment.from_file(file_name,"ogg") 
    chunk_length_ms = 10000 # pydub calculates in millisec 
    chunks = make_chunks(myaudio,chunk_length_ms) #Make chunks of one sec 
    for i, chunk in enumerate(chunks): 
        chunk_name = './chunked/' + file_name 
        print ("exporting", chunk_name) 
        chunk.export(chunk_name, format="ogg") 

all_file_names = os.listdir(Path)
try:
    os.makedirs('chunked') # creating a folder named chunked
except:
    pass
for each_file in all_file_names:
    process_sudio(Path + "/" + each_file)

# %%
# !pip install --upgrade AudioConverter
# Out:
# ...
#   Found existing installation: colorama 0.4.1
#     Uninstalling colorama-0.4.1:
#       Successfully uninstalled colorama-0.4.1
#   Found existing installation: click 8.0.4
#     Uninstalling click-8.0.4:
#       Successfully uninstalled click-8.0.4
# ...

# %%
from AudioCoverter import audioconvert
audioconvert convert 'Mini Project/train_audio/' 'chunked/' --output-format .mp3

# %%
def process_sudio(file_name):
    print(file_name)
    myaudio = AudioSegment.from_ogg(file_name,'ogg') 
    chunk_length_ms = 10000 # pydub calculates in millisec 
    chunks = make_chunks(myaudio,chunk_length_ms) #Make chunks of one sec 
    for i, chunk in enumerate(chunks): 
        chunk_name = './chunked/' + file_name 
        print ("exporting", chunk_name) 
        chunk.export(chunk_name, format="ogg")

# %%
process_sudio('XC27320.ogg')

# %%
# !pip install pydub

# %%
for i in dir_list:
    Path=Folder+'/'+i
    directory=os.listdir(Path)
    print(len(directory))
# Out:
# 16
# 6
# 10
# 14
# 2
# 51
# 12
# 47
# 196
# 15
# 462
# 100
# 271
# 179
# 3
# 41
# 14
# 56
# 135
# 13
# 20
# 500
# 24
# 5
# 15
# 7
# 20
# 52
# 38
# 134
# 318
# 10
# 176
# 120
# 16
# 12
# 39
# 16
# 177
# 208
# 55
# 500
# 194
# 3
# 2
# 476
# 14
# 6
# 340
# 32
# 239
# 108
# 30
# 463
# 11
# 101
# 17
# 16
# 48
# 273
# 21
# 16
# 20
# 9
# 3
# 3
# 20
# 322
# 500
# 8
# 37
# 8
# 78
# 43
# 17
# 12
# 79
# 3
# 13
# 84
# 99
# 7
# 149
# 83
# 44
# 19
# 16
# 500
# 27
# 3
# 1
# 74
# 59
# 142
# 500
# 31
# 387
# 112
# 106
# 78
# 14
# 21
# 228
# 53
# 7
# 62
# 75
# 38
# 186
# 162
# 7
# 3
# 42
# 36
# 75
# 39
# 40
# 39
# 32
# 78
# 30
# 248
# 156
# 311
# 192
# 35
# 151
# 116
# 77
# 128
# 3
# 500
# 97
# 11
# 22
# 6
# 146
# 107
# 123
# 101
# 19
# 71
# 343
# 40
# 23
# 45
# 28
# 23
# 76
# 20
# 67
# 89

# %%
Path
# Out:
# 'Mini Project/train_audio/zebdov'

# %%
#Importing library and thir function
from pydub import AudioSegment
from pydub.silence import split_on_silence

#reading from audio mp3 file
sound = AudioSegment.from_file('XC216038.ogg')

# spliting audio files
audio_chunks = split_on_silence(sound, min_silence_len=500, silence_thresh=-40 )

#loop is used to iterate over the output list
for i, chunk in enumerate(audio_chunks):
    output_file = "chunk{0}.mp3".format(i)
    print("Exporting file", output_file)
    chunk.export(output_file, format="mp3")

# chunk files saved as Output
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-080d72d87548> in <module>
#       4
#       5 #reading from audio mp3 file
# ----> 6 sound = AudioSegment.from_file('XC216038.ogg')
#       7
#       8 # spliting audio files
#
# E:\Anaconda\lib\site-packages\pydub\audio_segment.py in from_file(cls, file, format, codec, parameters, start_second, duration, **kwargs)
#     726             info = None
#     727         else:
# --> 728             info = mediainfo_json(orig_file, read_ahead_limit=read_ahead_limit)
#     729         if info:
#     730             audio_streams = [x for x in info['streams']
#
# E:\Anaconda\lib\site-packages\pydub\utils.py in mediainfo_json(filepath, read_ahead_limit)
#     272
#     273     command = [prober, '-of', 'json'] + command_args
# --> 274     res = Popen(command, stdin=stdin_parameter, stdout=PIPE, stderr=PIPE)
# ...

# %%
x,sr=librosa.load('XC216038.ogg')

# %%
x
# Out:
# array([ 5.8699476e-07, -3.4929221e-06,  1.1679319e-06, ...,
#         3.3483069e-05, -6.0393959e-06,  0.0000000e+00], dtype=float32)

# %%
len(x)
# Out:
# 1145089

# %%
sr
# Out:
# 22050

# %%
#!/usr/bin/env python

import argparse
import matplotlib.pyplot as plt
import librosa
import numpy as np
import os
from progressbar import ProgressBar

parser = argparse.ArgumentParser(
	description='Split audio into multiple files and save analysis.')
parser.add_argument('-i', '--input', type=str)
parser.add_argument('-o', '--output', type=str, default='transients')
parser.add_argument('-s', '--sr', type=int, default=44100)
args = parser.parse_args()

y, sr = librosa.load(args.input, sr=args.sr)
o_env = librosa.onset.onset_strength(y, sr=sr, feature=librosa.cqt)
onset_frames = librosa.onset.onset_detect(onset_envelope=o_env, sr=sr)

def prepare(y, sr=22050):
    y = librosa.to_mono(y)
    y = librosa.util.fix_length(y, sr) # 1 second of audio
    y = librosa.util.normalize(y)
    return y

def get_fingerprint(y, sr=22050):
    y = prepare(y, sr)
    cqt = librosa.cqt(y, sr=sr, hop_length=2048)
    return cqt.flatten('F')

def normalize(x):
    x -= x.min(axis=0)
    x /= x.max(axis=0)
    return x

def basename(file):
    file = os.path.basename(file)
    return os.path.splitext(file)[0]

vectors = []
words = []
filenames = []

onset_samples = list(librosa.frames_to_samples(onset_frames))
onset_samples = np.concatenate(onset_samples, len(y))
starts = onset_samples[0:-1]
stops = onset_samples[1:]
analysis_folder = args.output
samples_folder = os.path.join(args.output, 'samples')
try:
	os.makedirs(samples_folder)
except:
	pass
pbar = ProgressBar()
for i, (start, stop) in enumerate(pbar(zip(starts, stops))):
    audio = y[start:stop]
    filename = os.path.join(samples_folder, str(i) + '.wav')
    librosa.output.write_wav(filename, audio, sr)
    vector = get_fingerprint(audio, sr=sr)
    word = basename(filename)
    vectors.append(vector)
    words.append(word)
    filenames.append(filename)
np.savetxt(os.path.join(analysis_folder, 'vectors'), vectors, fmt='%.5f', delimiter='\t')
np.savetxt(os.path.join(analysis_folder, 'words'), words, fmt='%s')
np.savetxt(os.path.join(analysis_folder, 'filenames.txt'), filenames, fmt='%s')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-34-66ed93366b01> in <module>
#       6 import numpy as np
#       7 import os
# ----> 8 from progressbar import ProgressBar
#       9
#      10 parser = argparse.ArgumentParser(
#
# ModuleNotFoundError: No module named 'progressbar'

# %%
# !pip install ProgressBar
# Out:
# ...
#   Running setup.py bdist_wheel for ProgressBar: started
#   Running setup.py bdist_wheel for ProgressBar: finished with status 'done'
#   Stored in directory: C:\Users\91755\AppData\Local\pip\Cache\wheels\c0\e9\6b\ea01090205e285175842339aa3b491adeb4015206cda272ff0
# Successfully built ProgressBar
# ...
